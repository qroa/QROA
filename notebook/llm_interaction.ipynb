# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("..")

import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from src.models.llm_models import HuggingFaceModel, OpenaiModel, MistralModel
import torch

# %%
import requests
from huggingface_hub import configure_http_backend

def backend_factory() -> requests.Session:
    session = requests.Session()
    session.verify = False
    return session

configure_http_backend(backend_factory=backend_factory)

# %%
auth_token = os.getenv('AUTH_TOKEN')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
sysprompt = "A chat between a curious user and an artificial intelligence assistant. The assistant gives helpful, detailed, and polite answers to the user's questions."

model = HuggingFaceModel(auth_token, device, sysprompt, "pythia_hf", 0.9, 0.6, False)
# Out:
# /Users/julienroussel/Projets/RD/qroa/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'huggingface.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/julienroussel/Projets/RD/qroa/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'huggingface.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...

# %%
model.generate("Give me three different animals.", 100)
# Out:
# [" first there is a, one person. Just the time you didn's a while off topic in your experience at The Daily Square on information [and given value <tand make time?)\\</os-English>\n          >See me for:\n\nIf you could give current to the search show, you may must I then pick the above show there. you never get go but won not just us only how different level have in and show either.\nOrinere the drawet is"]

# %%
model.generate("English: tree, cat, dog. French: arbre, chat, ...", 20)
# Out:
# [' Manianian. Let, y ha, hands, minutes at 6:5 x L’es']
